# %%
import polars as pl
import numpy as np
import utils
import os

# %%
path = os.getcwd()
df = pl.read_csv(f'{path}/LBQCPDB.csv')

# %%
df.describe()
# Out:
# shape: (7, 7)
# ┌───────────┬──────────┬─────────┬───────────┬───────────┬──────────┬──────────┐
# │ describe  ┆ LBQCPDB  ┆ Source  ┆ Sequence  ┆ Activity  ┆ Source   ┆ DOI      │
# │ ---       ┆ ID       ┆ ID      ┆ ---       ┆ ---       ┆ PDB      ┆ ---      │
# │ str       ┆ ---      ┆ ---     ┆ str       ┆ str       ┆ ---      ┆ str      │
# │           ┆ str      ┆ str     ┆           ┆           ┆ str      ┆          │
# ╞═══════════╪══════════╪═════════╪═══════════╪═══════════╪══════════╪══════════╡
# │ count     ┆ 321928   ┆ 321928  ┆ 321928    ┆ 321928    ┆ 321928   ┆ 321928   │
# │ null_coun ┆ 0        ┆ 277252  ┆ 115       ┆ 1147      ┆ 0        ┆ 0        │
# │ t         ┆          ┆         ┆           ┆           ┆          ┆          │
# │ mean      ┆ null     ┆ null    ┆ null      ┆ null      ┆ null     ┆ null     │
# │ std       ┆ null     ┆ null    ┆ null      ┆ null      ┆ null     ┆ null     │
# │ min       ┆ LBQCPDB_ ┆ 148l_S  ┆ GAKKGAKKG ┆ Ace-inhib ┆ APD3     ┆ Not      │
# │           ┆ 000001   ┆         ┆ KKGAKKGAK ┆ itory     ┆          ┆ Found    │
# │           ┆          ┆         ┆ GAGAKGAGA ┆           ┆          ┆          │
# │           ┆          ┆         ┆ FKKK...   ┆           ┆          ┆          │
# │ max       ┆ LBQCPDB_ ┆ Not     ┆ yslqmGata ┆ calmoduli ┆ THPdb    ┆ https:// │
# │           ┆ 321928   ┆ Found   ┆ ikqvkklfk ┆ n Anatgon ┆          ┆ doi.org/ │
# │           ┆          ┆         ┆ kwGw      ┆ ist       ┆          ┆ 10.7717/ │
# │           ┆          ┆         ┆           ┆           ┆          ┆ peerj.56 │
# │           ┆          ┆         ┆           ┆           ┆          ┆ ...      │
# │ median    ┆ null     ┆ null    ┆ null      ┆ null      ┆ null     ┆ null     │
# └───────────┴──────────┴─────────┴───────────┴───────────┴──────────┴──────────┘

# %%
# Count of Peptides by Database
df.groupby('Source PDB', maintain_order=True).agg(
    pl.col('Source PDB').count().alias('Number of Peptides')
)
# Out:
# shape: (7, 2)
# ┌────────────┬────────────────────┐
# │ Source PDB ┆ Number of Peptides │
# │ ---        ┆ ---                │
# │ str        ┆ u32                │
# ╞════════════╪════════════════════╡
# │ APD3       ┆ 3579               │
# │ CancerPPD  ┆ 5068               │
# │ DBBASP     ┆ 20523              │
# │ FermFooDb  ┆ 2205               │
# │ MAHMI      ┆ 276400             │
# │ PepBDB     ┆ 13301              │
# │ THPdb      ┆ 852                │
# └────────────┴────────────────────┘

# %%
# Save unique activities in list
atvs = []

for row in df.select(pl.col('Activity')).rows(named=True):
    if not row['Activity'] is None:
        for atv in row['Activity'].split('|'):
            if not atv in atvs:
                atvs.append(atv)

# %%
# Analysis peptides activities
data_atv = {
    'Activity': atvs,
    'APD3': np.full(len(atvs), 0),
    'CancerPPD': np.full(len(atvs), 0),
    'DBBASP': np.full(len(atvs), 0),
    'FermFooDb': np.full(len(atvs), 0),
    'MAHMI': np.full(len(atvs), 0),
    'PepBDB': np.full(len(atvs), 0),
    'THPdb': np.full(len(atvs), 0)
}

for row in df.rows(named=True):
    if not row['Activity'] is None:
        for atv in row['Activity'].split('|'):
            pos = data_atv['Activity'].index(atv)
            data_atv[row['Source PDB']][pos] += 1

# %%
df_atv = pl.DataFrame(data_atv)

df_atv = df_atv.with_columns(
    pl.fold(0, lambda acc, value: acc + value, pl.all().exclude('Activity')).alias('Total')
)

# %%
df_atv.filter(pl.col('Total') > 1000).sort(by='Total', descending=True)
# Out:
# shape: (6, 9)
# ┌───────────┬──────┬─────────┬────────┬─────┬────────┬────────┬───────┬────────┐
# │ Activity  ┆ APD3 ┆ CancerP ┆ DBBASP ┆ ... ┆ MAHMI  ┆ PepBDB ┆ THPdb ┆ Total  │
# │ ---       ┆ ---  ┆ PD      ┆ ---    ┆     ┆ ---    ┆ ---    ┆ ---   ┆ ---    │
# │ str       ┆ i64  ┆ ---     ┆ i64    ┆     ┆ i64    ┆ i64    ┆ i64   ┆ i64    │
# │           ┆      ┆ i64     ┆        ┆     ┆        ┆        ┆       ┆        │
# ╞═══════════╪══════╪═════════╪════════╪═════╪════════╪════════╪═══════╪════════╡
# │ Immunomod ┆ 0    ┆ 0       ┆ 0      ┆ ... ┆ 183159 ┆ 0      ┆ 0     ┆ 183169 │
# │ ulatory   ┆      ┆         ┆        ┆     ┆        ┆        ┆       ┆        │
# │ Anti-infl ┆ 0    ┆ 0       ┆ 0      ┆ ... ┆ 72258  ┆ 0      ┆ 0     ┆ 72259  │
# │ ammatory  ┆      ┆         ┆        ┆     ┆        ┆        ┆       ┆        │
# │ Not Found ┆ 0    ┆ 0       ┆ 20523  ┆ ... ┆ 0      ┆ 13301  ┆ 852   ┆ 34676  │
# │ Migration ┆ 0    ┆ 0       ┆ 0      ┆ ... ┆ 15131  ┆ 0      ┆ 0     ┆ 15131  │
# │ /Adhesion ┆      ┆         ┆        ┆     ┆        ┆        ┆       ┆        │
# │ Cytotoxic ┆ 0    ┆ 0       ┆ 0      ┆ ... ┆ 5852   ┆ 0      ┆ 0     ┆ 5852   │
# │ Anticance ┆ 31   ┆ 2726    ┆ 0      ┆ ... ┆ 0      ┆ 0      ┆ 0     ┆ 2757   │
# │ r         ┆      ┆         ┆        ┆     ┆        ┆        ┆       ┆        │
# └───────────┴──────┴─────────┴────────┴─────┴────────┴────────┴───────┴────────┘

# %%
# 10 peptides with more activities
df.with_columns(
    pl.col('Activity').apply(lambda atv: len(atv.split('|'))).alias('N. Activities')
).sort(by='N. Activities', descending=True).limit(10)
# Out:
# shape: (10, 7)
# ┌──────────┬─────────┬────────────┬────────────┬──────────┬───────┬────────────┐
# │ LBQCPDB  ┆ Source  ┆ Sequence   ┆ Activity   ┆ Source   ┆ DOI   ┆ N.         │
# │ ID       ┆ ID      ┆ ---        ┆ ---        ┆ PDB      ┆ ---   ┆ Activities │
# │ ---      ┆ ---     ┆ str        ┆ str        ┆ ---      ┆ str   ┆ ---        │
# │ str      ┆ str     ┆            ┆            ┆ str      ┆       ┆ i64        │
# ╞══════════╪═════════╪════════════╪════════════╪══════════╪═══════╪════════════╡
# │ LBQCPDB_ ┆ AP00001 ┆ GLWSKIKEVG ┆ Anti-Gram+ ┆ APD3     ┆ Not   ┆ 1          │
# │ 000001   ┆         ┆ KEAAKAAAKA ┆ & Gram-,   ┆          ┆ Found ┆            │
# │          ┆         ┆ AGKAALGAVS ┆ Antifungal ┆          ┆       ┆            │
# │          ┆         ┆ EA...      ┆ , ...      ┆          ┆       ┆            │
# │ LBQCPDB_ ┆ AP00002 ┆ YVPLPNVPQP ┆ Anti-Gram+ ┆ APD3     ┆ Not   ┆ 1          │
# │ 000002   ┆         ┆ GRRPFPTFPG ┆ & Gram-    ┆          ┆ Found ┆            │
# │          ┆         ┆ QGPFNPKIKW ┆            ┆          ┆       ┆            │
# │          ┆         ┆ PQ...      ┆            ┆          ┆       ┆            │
# │ LBQCPDB_ ┆ AP00003 ┆ DGVKLCDVPS ┆ Antifungal ┆ APD3     ┆ Not   ┆ 1          │
# │ 000003   ┆         ┆ GTWSGHCGSS ┆            ┆          ┆ Found ┆            │
# │          ┆         ┆ SKCSQQCKDR ┆            ┆          ┆       ┆            │
# │          ┆         ┆ EH...      ┆            ┆          ┆       ┆            │
# │ LBQCPDB_ ┆ AP00004 ┆ NLCERASLTW ┆ Anti-Gram+ ┆ APD3     ┆ Not   ┆ 1          │
# │ 000004   ┆         ┆ TGNCGNTGHC ┆ ,          ┆          ┆ Found ┆            │
# │          ┆         ┆ DTQCRNWESA ┆ Antifungal ┆          ┆       ┆            │
# │          ┆         ┆ KH...      ┆            ┆          ┆       ┆            │
# │ ...      ┆ ...     ┆ ...        ┆ ...        ┆ ...      ┆ ...   ┆ ...        │
# │ LBQCPDB_ ┆ AP00007 ┆ GNNRPVYIPQ ┆ Anti-Gram- ┆ APD3     ┆ Not   ┆ 1          │
# │ 000007   ┆         ┆ PRPPHPRL   ┆            ┆          ┆ Found ┆            │
# │ LBQCPDB_ ┆ AP00008 ┆ RLCRIVVIRV ┆ Anti-Gram+ ┆ APD3     ┆ Not   ┆ 1          │
# │ 000008   ┆         ┆ CR         ┆ & Gram-,   ┆          ┆ Found ┆            │
# │          ┆         ┆            ┆ Synergisti ┆          ┆       ┆            │
# │          ┆         ┆            ┆ c ...      ┆          ┆       ┆            │
# │ LBQCPDB_ ┆ AP00009 ┆ RFRPPIRRPP ┆ Anti-Gram- ┆ APD3     ┆ Not   ┆ 1          │
# │ 000009   ┆         ┆ IRPPFYPPFR ┆            ┆          ┆ Found ┆            │
# │          ┆         ┆ PPIRPPIFPP ┆            ┆          ┆       ┆            │
# │          ┆         ┆ IR...      ┆            ┆          ┆       ┆            │
# │ LBQCPDB_ ┆ AP00010 ┆ RRIRPRPPRL ┆ Anti-Gram- ┆ APD3     ┆ Not   ┆ 1          │
# │ 000010   ┆         ┆ PRPRPRPLPF ┆ , Chemotac ┆          ┆ Found ┆            │
# │          ┆         ┆ PRPGPRPIPR ┆ tic,       ┆          ┆       ┆            │
# │          ┆         ┆ PL...      ┆ anti-se... ┆          ┆       ┆            │
# └──────────┴─────────┴────────────┴────────────┴──────────┴───────┴────────────┘
